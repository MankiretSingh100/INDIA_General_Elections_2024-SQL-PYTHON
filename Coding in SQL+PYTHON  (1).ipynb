# %% [markdown]
# #  PROJECT :INDIA GENERAL ELECTIONS RESULT ANALYSIS 2024

# %% [markdown]
# # Executed this project using SQL within Jupyter Notebook, integrated with Python.

# %% [markdown]
# # IMPORTING THE PANDAS LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # CONNECTING WITH SQL SERVER

# %%
import mysql.connector

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sqlalchemy import create_engine

# %%
mydb = mysql.connector.connect(
    host='localhost',
    user='root',
    password='password',
    database='india_general_elections_2024',  # fix typo here
    use_pure=True)

# %%
mydb

# %%
pd.read_sql_query("""SELECT * FROM india_general_elections_2024.constituencywise_details;""",mydb)
# Out:
# C:\Users\Mankirat\AppData\Local\Temp\ipykernel_22588\3587043906.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""SELECT * FROM india_general_elections_2024.constituencywise_details;""",mydb)
#      S.N.                      Candidate                     Party  EVM Votes  \
# 0       1              DR JITENDRA SINGH    Bharatiya Janata Party     566833
# 1       2                   CH LAL SINGH  Indian National Congress     444151
# 2       3            GHULAM MOHD SAROORI               Independent      39519
# 3       4                     MEHRAJ DIN               Independent       9055
# 4       5                     AMIT KUMAR       Bahujan Samaj Party       8559
# ..    ...                            ...                       ...        ...
# ...

# %%
engine = create_engine("mysql+pymysql://root:password@localhost/india_general_elections_2024")

# %%
pd.read_sql_query("""SELECT * FROM india_general_elections_2024.constituencywise_details;""",engine)
# Out:
#      S.N.                      Candidate                     Party  EVM Votes  \
# 0       1              DR JITENDRA SINGH    Bharatiya Janata Party     566833
# 1       2                   CH LAL SINGH  Indian National Congress     444151
# 2       3            GHULAM MOHD SAROORI               Independent      39519
# 3       4                     MEHRAJ DIN               Independent       9055
# 4       5                     AMIT KUMAR       Bahujan Samaj Party       8559
# ..    ...                            ...                       ...        ...
# 507    27  SALIMUDDIN KHALILUDDIN SHAIKH               Independent        370
# 508    28      DR. SACHIN SAHEBRAO PATIL               Independent        346
# 509    29                           NOTA         None of the Above      11603
# 510     1               BHAJAN LAL JATAV  Indian National Congress     525379
# 511     2                      INDU DEVI    Bharatiya Janata Party     426798
#
# ...

# %% [markdown]
# # Task1:  Total number of seats in Parliament Constituency

# %%
df1=pd.read_sql_query(""" SELECT DISTINCT
    COUNT(`Parliament Constituency`)
FROM
    constituencywise_results;""",engine)

# %%
df1
# Out:
#    COUNT(`Parliament Constituency`)
# 0                               543

# %% [markdown]
# # conclusion :Parliament Constituency have total 543 Seats

# %% [markdown]
#   # -- Task 2 : what are the total number of seats available for elections for each states

# %%
T2=pd.read_sql_query(""" select s.State as State_name , count(cr.`Constituency ID`) as total__seats_available
    from states as s 
    join state_results as sr
    on s.`State ID`=sr.`State ID` 
    join constituencywise_results as cr
    on cr.`Parliament Constituency` = sr.`Parliament Constituency` 
    group by State_name 
    order by State_name ;""" ,engine)

# %%
T2
# Out:
#                               State_name  total__seats_available
# 0              Andaman & Nicobar Islands                       1
# 1                         Andhra Pradesh                      25
# 2                      Arunachal Pradesh                       2
# 3                                  Assam                      14
# 4                                  Bihar                      40
# 5                             Chandigarh                       1
# 6                           Chhattisgarh                      11
# 7   Dadra & Nagar Haveli and Daman & Diu                       2
# 8                                  Delhi                       7
# 9                                    Goa                       2
# 10                               Gujarat                      26
# 11                               Haryana                      10
# 12                      Himachal Pradesh                       4
# ...

# %% [markdown]
#  # -- Task 3 : Total seats won by NDA alliance

# %%
T3=pd.read_sql_query("""SELECT 
    SUM(CASE
        WHEN
            party IN ('Bharatiya Janata Party - BJP' , 'Telugu Desam - TDP',
                'Janata Dal  (United) - JD(U)',
                'Shiv Sena - SHS',
                'AJSU Party - AJSUP',
                'Apna Dal (Soneylal) - ADAL',
                'Asom Gana Parishad - AGP',
                'Hindustani Awam Morcha (Secular) - HAMS',
                'Janasena Party - JnP',
                'Janata Dal  (Secular) - JD(S)',
                'Lok Janshakti Party(Ram Vilas) - LJPRV',
                'Nationalist Congress Party - NCP',
                'Rashtriya Lok Dal - RLD',
                'Sikkim Krantikari Morcha - SKM')
        THEN
            `Won`
        ELSE 0
    END) AS NDA_Total_Seats_Won
FROM
    partywise_results;
""",engine)

# %%
T3
# Out:
#    NDA_Total_Seats_Won
# 0                292.0

# %% [markdown]
# # CONCLUSION  :Total seats won by NDA alliance was 292 seats

# %% [markdown]
#  # --  Task 4 :  Total seats won by NDA alliance parties

# %%
T4=pd.read_sql_query("""  SELECT 
    party as Party_Name,
    won as Seats_Won
FROM 
    partywise_results
WHERE 
    party IN (
        'Bharatiya Janata Party - BJP', 
        'Telugu Desam - TDP', 
		'Janata Dal  (United) - JD(U)',
        'Shiv Sena - SHS', 
        'AJSU Party - AJSUP', 
        'Apna Dal (Soneylal) - ADAL', 
        'Asom Gana Parishad - AGP',
        'Hindustani Awam Morcha (Secular) - HAMS', 
        'Janasena Party - JnP', 
		'Janata Dal  (Secular) - JD(S)',
        'Lok Janshakti Party(Ram Vilas) - LJPRV', 
        'Nationalist Congress Party - NCP',
        'Rashtriya Lok Dal - RLD', 
        'Sikkim Krantikari Morcha - SKM'
    )
ORDER BY Seats_Won DESC;""",engine)

# %%
T4
# Out:
#                                  Party_Name  Seats_Won
# 0              Bharatiya Janata Party - BJP        240
# 1                        Telugu Desam - TDP         16
# 2              Janata Dal  (United) - JD(U)         12
# 3                           Shiv Sena - SHS          7
# 4    Lok Janshakti Party(Ram Vilas) - LJPRV          5
# 5             Janata Dal  (Secular) - JD(S)          2
# 6                      Janasena Party - JnP          2
# 7                   Rashtriya Lok Dal - RLD          2
# 8                  Asom Gana Parishad - AGP          1
# 9                        AJSU Party - AJSUP          1
# 10  Hindustani Awam Morcha (Secular) - HAMS          1
# 11         Nationalist Congress Party - NCP          1
# 12           Sikkim Krantikari Morcha - SKM          1
# 13               Apna Dal (Soneylal) - ADAL          1

# %% [markdown]
# # CONCLUSION : NDA alliance parties like BJP won by 240

# %% [markdown]
# # -- Task 5 : Total Seats Won by I.N.D.I.A. Allianz

# %%
T5=pd.read_sql_query("""
SELECT 
    SUM(CASE 
            WHEN party IN (
                'Indian National Congress - INC',
                'Aam Aadmi Party - AAAP',
                'All India Trinamool Congress - AITC',
                'Bharat Adivasi Party - BHRTADVSIP',
                'Communist Party of India  (Marxist) - CPI(M)',
                'Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)',
                'Communist Party of India - CPI',
                'Dravida Munnetra Kazhagam - DMK',
                'Indian Union Muslim League - IUML',
                'Nat`Jammu & Kashmir National Conference - JKN',
                'Jharkhand Mukti Morcha - JMM',
                'Jammu & Kashmir National Conference - JKN',
                'Kerala Congress - KEC',
                'Marumalarchi Dravida Munnetra Kazhagam - MDMK',
                'Nationalist Congress Party Sharadchandra Pawar - NCPSP',
                'Rashtriya Janata Dal - RJD',
                'Rashtriya Loktantrik Party - RLTP',
                'Revolutionary Socialist Party - RSP',
                'Samajwadi Party - SP',
                'Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT',
                'Viduthalai Chiruthaigal Katchi - VCK'
            ) THEN `Won`
            ELSE 0 
        END) AS INDIA_Total_Seats_Won
FROM 
    partywise_results ;""",engine)

# %%
T5
# Out:
#    INDIA_Total_Seats_Won
# 0                  234.0

# %% [markdown]
# # -- Task 6 : Seats Won by I.N.D.I.A. Allianz Parties

# %%
T6=pd.read_sql_query("""SELECT 
    party as Party_Name,
    won as Seats_Won
FROM 
    partywise_results
WHERE 
    party IN (
        'Indian National Congress - INC',
                'Aam Aadmi Party - AAAP',
                'All India Trinamool Congress - AITC',
                'Bharat Adivasi Party - BHRTADVSIP',
                'Communist Party of India  (Marxist) - CPI(M)',
                'Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)',
                'Communist Party of India - CPI',
                'Dravida Munnetra Kazhagam - DMK',
                'Indian Union Muslim League - IUML',
                'Nat`Jammu & Kashmir National Conference - JKN',
                'Jharkhand Mukti Morcha - JMM',
                'Jammu & Kashmir National Conference - JKN',
                'Kerala Congress - KEC',
                'Marumalarchi Dravida Munnetra Kazhagam - MDMK',
                'Nationalist Congress Party Sharadchandra Pawar - NCPSP',
                'Rashtriya Janata Dal - RJD',
                'Rashtriya Loktantrik Party - RLTP',
                'Revolutionary Socialist Party - RSP',
                'Samajwadi Party - SP',
                'Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT',
                'Viduthalai Chiruthaigal Katchi - VCK'
    )
ORDER BY Seats_Won DESC ;
""",engine)

# %%
T6
# Out:
#                                            Party_Name  Seats_Won
# 0                      Indian National Congress - INC         99
# 1                                Samajwadi Party - SP         37
# 2                 All India Trinamool Congress - AITC         29
# 3                     Dravida Munnetra Kazhagam - DMK         22
# 4      Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT          9
# 5   Nationalist Congress Party Sharadchandra Pawar...          8
# 6        Communist Party of India  (Marxist) - CPI(M)          4
# 7                          Rashtriya Janata Dal - RJD          4
# 8                              Aam Aadmi Party - AAAP          3
# 9                   Indian Union Muslim League - IUML          3
# 10                       Jharkhand Mukti Morcha - JMM          3
# 11                     Communist Party of India - CPI          2
# 12  Communist Party of India  (Marxist-Leninist)  ...          2
# ...

# %% [markdown]
# # TASK 7  Add new column field in table partywise_results to get the Party Allianz as NDA, I.N.D.I.A and OTHER

# %% [markdown]
# #  FIRST IMPORT LIBRARY "sqlalchemy" , so that we can add new column into the given data set

# %%
from sqlalchemy import tex

# %% [markdown]
# # firstly alter the table name then add the column according to the task

# %%
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE partywise_results
        ADD party_alliance VARCHAR(50);
    """))

# %%
df=pd.read_sql_query("""SELECT * FROM partywise_results ;""",engine)

# %%
df
# Out:
#                                                 Party  Won  Party ID  \
# 0                              Aam Aadmi Party - AAAP    3         1
# 1                            Asom Gana Parishad - AGP    1        83
# 2      All India Majlis-E-Ittehadul Muslimeen - AIMIM    1       118
# 3                 All India Trinamool Congress - AITC   29       140
# 4                                  AJSU Party - AJSUP    1       160
# 5                        Bharatiya Janata Party - BJP  240       369
# 6                      Communist Party of India - CPI    2       544
# 7   Communist Party of India  (Marxist-Leninist)  ...    2       545
# 8        Communist Party of India  (Marxist) - CPI(M)    4       547
# 9                     Dravida Munnetra Kazhagam - DMK   22       582
# 10            Hindustani Awam Morcha (Secular) - HAMS    1       664
# 11                     Indian National Congress - INC   99       742
# 12                                  Independent - IND    7       743
# ...

# %% [markdown]
# #  new column name "party-alliance" is created and now insert tha data into it

# %% [markdown]
# # add th data of I.N.D.I.A Allianz

# %%
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE partywise_results
        SET party_alliance = 'I.N.D.I.A'
        WHERE party IN (
            'Indian National Congress - INC',
            'Aam Aadmi Party - AAAP',
            'All India Trinamool Congress - AITC',
            'Bharat Adivasi Party - BHRTADVSIP',
            'Communist Party of India  (Marxist) - CPI(M)',
            'Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)',
            'Communist Party of India - CPI',
            'Dravida Munnetra Kazhagam - DMK',	
            'Indian Union Muslim League - IUML',
            'Jammu & Kashmir National Conference - JKN',
            'Jharkhand Mukti Morcha - JMM',
            'Kerala Congress - KEC',
            'Marumalarchi Dravida Munnetra Kazhagam - MDMK',
            'Nationalist Congress Party Sharadchandra Pawar - NCPSP',
            'Rashtriya Janata Dal - RJD',
            'Rashtriya Loktantrik Party - RLTP',
            'Revolutionary Socialist Party - RSP',
            'Samajwadi Party - SP',
            'Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT',
            'Viduthalai Chiruthaigal Katchi - VCK'
        );
    """))

# %%
df1=pd.read_sql_query("""SELECT * FROM partywise_results WHERE party_alliance = 'I.N.D.I.A' ;""",engine)

# %%
df1
# Out:
#                                                 Party  Won  Party ID  \
# 0                              Aam Aadmi Party - AAAP    3         1
# 1                 All India Trinamool Congress - AITC   29       140
# 2                      Communist Party of India - CPI    2       544
# 3   Communist Party of India  (Marxist-Leninist)  ...    2       545
# 4        Communist Party of India  (Marxist) - CPI(M)    4       547
# 5                     Dravida Munnetra Kazhagam - DMK   22       582
# 6                      Indian National Congress - INC   99       742
# 7                   Indian Union Muslim League - IUML    3       772
# 8           Jammu & Kashmir National Conference - JKN    2       834
# 9                        Jharkhand Mukti Morcha - JMM    3       852
# 10                              Kerala Congress - KEC    1       911
# 11      Marumalarchi Dravida Munnetra Kazhagam - MDMK    1      1046
# 12                         Rashtriya Janata Dal - RJD    4      1420
# ...

# %%
df = pd.read_sql_query("SELECT DISTINCT party FROM partywise_results;", engine)
print(df)
# Out:
#                                                 party
# 0                              Aam Aadmi Party - AAAP
# 1                            Asom Gana Parishad - AGP
# 2      All India Majlis-E-Ittehadul Muslimeen - AIMIM
# 3                 All India Trinamool Congress - AITC
# 4                                  AJSU Party - AJSUP
# 5                        Bharatiya Janata Party - BJP
# 6                      Communist Party of India - CPI
# 7   Communist Party of India  (Marxist-Leninist)  ...
# 8        Communist Party of India  (Marxist) - CPI(M)
# 9                     Dravida Munnetra Kazhagam - DMK
# 10            Hindustani Awam Morcha (Secular) - HAMS
# 11                     Indian National Congress - INC
# 12                                  Independent - IND
# 13                  Indian Union Muslim League - IUML
# 14                      Janata Dal  (Secular) - JD(S)
# 15                       Janata Dal  (United) - JD(U)
# ...

# %%
df = pd.read_sql_query("SELECT party, party_alliance FROM partywise_results WHERE party_alliance = 'I.N.D.I.A';", engine)
df
# Out:
#                                                 party party_alliance
# 0                              Aam Aadmi Party - AAAP      I.N.D.I.A
# 1                 All India Trinamool Congress - AITC      I.N.D.I.A
# 2                      Communist Party of India - CPI      I.N.D.I.A
# 3   Communist Party of India  (Marxist-Leninist)  ...      I.N.D.I.A
# 4        Communist Party of India  (Marxist) - CPI(M)      I.N.D.I.A
# 5                     Dravida Munnetra Kazhagam - DMK      I.N.D.I.A
# 6                      Indian National Congress - INC      I.N.D.I.A
# 7                   Indian Union Muslim League - IUML      I.N.D.I.A
# 8           Jammu & Kashmir National Conference - JKN      I.N.D.I.A
# 9                        Jharkhand Mukti Morcha - JMM      I.N.D.I.A
# 10                              Kerala Congress - KEC      I.N.D.I.A
# 11      Marumalarchi Dravida Munnetra Kazhagam - MDMK      I.N.D.I.A
# 12                         Rashtriya Janata Dal - RJD      I.N.D.I.A
# ...

# %% [markdown]
# # --  adding the dada of NDA Allianz into new column which is created in above

# %%
from sqlalchemy import text

with engine.begin() as conn:  # ensures commit
    conn.execute(text("""
        UPDATE partywise_results
        SET party_alliance = 'NDA'
        WHERE party IN (
            'Bharatiya Janata Party - BJP',
            'Telugu Desam - TDP',
            'Janata Dal  (United) - JD(U)',
            'Shiv Sena - SHS',
            'AJSU Party - AJSUP',
            'Apna Dal (Soneylal) - ADAL',
            'Asom Gana Parishad - AGP',
            'Hindustani Awam Morcha (Secular) - HAMS',
            'Janasena Party - JnP',
            'Janata Dal  (Secular) - JD(S)',
            'Lok Janshakti Party(Ram Vilas) - LJPRV',
            'Nationalist Congress Party - NCP',
            'Rashtriya Lok Dal - RLD',
            'Sikkim Krantikari Morcha - SKM'
        );
    """))

# %%
df = pd.read_sql_query("""
    SELECT party, party_alliance 
    FROM partywise_results 
    WHERE party_alliance = 'NDA';
""", engine)

df
# Out:
#                                       party party_alliance
# 0                  Asom Gana Parishad - AGP            NDA
# 1                        AJSU Party - AJSUP            NDA
# 2              Bharatiya Janata Party - BJP            NDA
# 3   Hindustani Awam Morcha (Secular) - HAMS            NDA
# 4             Janata Dal  (Secular) - JD(S)            NDA
# 5              Janata Dal  (United) - JD(U)            NDA
# 6                      Janasena Party - JnP            NDA
# 7          Nationalist Congress Party - NCP            NDA
# 8                   Rashtriya Lok Dal - RLD            NDA
# 9            Sikkim Krantikari Morcha - SKM            NDA
# 10                       Telugu Desam - TDP            NDA
# 11               Apna Dal (Soneylal) - ADAL            NDA
# 12   Lok Janshakti Party(Ram Vilas) - LJPRV            NDA
# 13                          Shiv Sena - SHS            NDA

# %% [markdown]
# #  inserting tha data of OTHERS party into the column

# %%
with engine.begin() as conn:  # ensures the update is committed
    conn.execute(text("""
        UPDATE partywise_results
        SET party_alliance = 'OTHER'
        WHERE party_alliance IS NULL;
    """))

# %%
df = pd.read_sql_query("""
    SELECT party, party_alliance
    FROM partywise_results
    WHERE party_alliance = 'OTHER';
""", engine)

df.head()
# Out:
#                                             party party_alliance
# 0  All India Majlis-E-Ittehadul Muslimeen - AIMIM          OTHER
# 1                               Independent - IND          OTHER
# 2                       Shiromani Akali Dal - SAD          OTHER
# 3   Yuvajana Sramika Rythu Congress Party - YSRCP          OTHER
# 4         United Peopleâ€™s Party, Liberal - UPPL          OTHER

# %%
df = pd.read_sql_query("""SELECT * FROM partywise_results ;""", engine)

# %%
df
# Out:
#                                                 Party  Won  Party ID  \
# 0                              Aam Aadmi Party - AAAP    3         1
# 1                            Asom Gana Parishad - AGP    1        83
# 2      All India Majlis-E-Ittehadul Muslimeen - AIMIM    1       118
# 3                 All India Trinamool Congress - AITC   29       140
# 4                                  AJSU Party - AJSUP    1       160
# 5                        Bharatiya Janata Party - BJP  240       369
# 6                      Communist Party of India - CPI    2       544
# 7   Communist Party of India  (Marxist-Leninist)  ...    2       545
# 8        Communist Party of India  (Marxist) - CPI(M)    4       547
# 9                     Dravida Munnetra Kazhagam - DMK   22       582
# 10            Hindustani Awam Morcha (Secular) - HAMS    1       664
# 11                     Indian National Congress - INC   99       742
# 12                                  Independent - IND    7       743
# ...

# %% [markdown]
# # Task 8 :Which party alliance (NDA, I.N.D.I.A, or OTHER) won the most seats across all states?

# %%
T8 = pd.read_sql_query("""SELECT 
    p.party_alliance,
    COUNT(cr.`Constituency ID`) AS Seats_Won
FROM 
    constituencywise_results cr
JOIN 
    partywise_results p 
    ON cr.`Party ID` = p.`Party ID`
GROUP BY 
    p.party_alliance
ORDER BY 
    Seats_Won DESC;
""", engine)

# %%
T8
# Out:
#   party_alliance  Seats_Won
# 0            NDA        292
# 1      I.N.D.I.A        234
# 2          OTHER         17

# %% [markdown]
# #  Task 9 : Winning candidate's name, their party name, total votes, and the margin of victory for a specific state and constituency?

# %%
T9 = pd.read_sql_query("""SELECT cr.`Winning Candidate`,
p.`Party`,
p.`party_alliance`, 
cr.`Total Votes`, 
cr.`Margin`, 
cr.`Constituency Name`,
s.State
FROM constituencywise_results as cr
JOIN partywise_results as p
ON cr.`Party ID` = p.`Party ID`
JOIN state_results as sr
ON cr.`Parliament Constituency` = sr.`Parliament Constituency`
JOIN states as s 
ON sr.`State ID` = s.`State ID`
WHERE s.State = 'Uttar Pradesh'
AND 
cr.`Constituency Name` = 'AMETHI';""", engine)

# %%
T9
# Out:
#   Winning Candidate                           Party party_alliance  \
# 0       KISHORI LAL  Indian National Congress - INC      I.N.D.I.A
#
#    Total Votes  Margin Constituency Name          State
# 0       539228  167196            AMETHI  Uttar Pradesh

# %% [markdown]
# #  Task 10 : What is the distribution of EVM votes versus postal votes for candidates in a specific constituency?

# %%
T10 = pd.read_sql_query(""" 
SELECT 
    cd.`EVM Votes`,
    cd.`Postal Votes`,
    cd.`Candidate`,
    cd.`Total Votes`,
    cr.`Constituency Name`
FROM
    constituencywise_details AS cd
        JOIN
    constituencywise_results AS cr ON cr.`Constituency ID` = cd.`Constituency ID`
WHERE
    cr.`Constituency Name` = 'ETAH'
ORDER BY cd.`Total Votes` DESC;


""", engine)

# %%
T10
# Out:
#     EVM Votes  Postal Votes                    Candidate  Total Votes  \
# 0      474263          1545                DEVESH SHAKYA       475808
# 1      446748          1008  RAJVEER SINGH (RAJU BHAIYA)       447756
# 2       71407           178      MOHAMMAD IRFAN ADVOCATE        71585
# 3        5145            11                         NOTA         5156
# 4        3944             5                 ANUPAM KUMAR         3949
# 5        1728             0                KAILASH KUMAR         1728
# 6        1261             4                      DANVEER         1265
# 7         985             7              UDAY VEER SINGH          992
# 8         777             3                  ASHOK KUMAR          780
# 9         742             5               VIABHAV MISHRA          747
# 10        609             6                   AMAR SINGH          615
#
#    Constituency Name
# 0               ETAH
# 1               ETAH
# 2               ETAH
# 3               ETAH
# ...

# %% [markdown]
# #  Task 11 : Which parties won the most seats in s State, and how many seats did each party win?

# %%
T11= pd.read_sql_query("""select pr.`party`,
count(cr.`Constituency ID`) as Seats_Won
from partywise_results as pr
join constituencywise_results aS cr
on cr.`Party ID`=pr.`Party ID`
join state_results as sr
on sr.`Parliament Constituency` = cr.`Parliament Constituency`
join states as s
on s.`State ID`=sr.`State ID`
where s.State="Andhra Pradesh"
group by 1
order by 2 desc;
""", engine)

# %%
T11
# Out:
#                                            party  Seats_Won
# 0                             Telugu Desam - TDP         16
# 1  Yuvajana Sramika Rythu Congress Party - YSRCP          4
# 2                   Bharatiya Janata Party - BJP          3
# 3                           Janasena Party - JnP          2

# %% [markdown]
# # Task  12 : at is the total number of seats won by each party alliance (NDA, I.N.D.I.A, and OTHER) in each state for the India Elections 2024

# %%
T12 = pd.read_sql_query("""select s.State as state_name ,
sum(
case 
when pr.party_alliance="I.N.D.I.A" THEN 1 ELSE 0 END ) AS INDIA_Seats_Won,
Sum(
case 
when pr.party_alliance="NDA" THEN 1 ELSE 0 END ) AS NDA_Seats_Won,
sum(
case 
when pr.party_alliance="OTHER" THEN 1 ELSE 0 END ) AS OTHER_Seats_Won
From partywise_results as pr
join constituencywise_results aS cr
on cr.`Party ID`=pr.`Party ID`
join state_results as sr
on sr.`Parliament Constituency` = cr.`Parliament Constituency`
join states as s
on s.`State ID`=sr.`State ID`
group by 1
order by 1;
""", engine)

# %%
T12
# Out:
#                               state_name  INDIA_Seats_Won  NDA_Seats_Won  \
# 0              Andaman & Nicobar Islands              0.0            1.0
# 1                         Andhra Pradesh              0.0           21.0
# 2                      Arunachal Pradesh              0.0            2.0
# 3                                  Assam              3.0           10.0
# 4                                  Bihar              9.0           30.0
# 5                             Chandigarh              1.0            0.0
# 6                           Chhattisgarh              1.0           10.0
# 7   Dadra & Nagar Haveli and Daman & Diu              0.0            1.0
# 8                                  Delhi              0.0            7.0
# 9                                    Goa              1.0            1.0
# 10                               Gujarat              1.0           25.0
# 11                               Haryana              5.0            5.0
# ...

# %% [markdown]
# #  Task 13 :
# # For the state of Maharashtra, what are the total number of seats, total number of candidates, total number of parties, total votes (including EVM and postal), and the breakdown of EVM and postal votes?

# %%
T13 = pd.read_sql_query("""select count(distinct cr.`Constituency ID`) as Total_Seats,
 count(distinct cd.`Candidate`) as Total_Candidates,
 count(distinct pr.`party`) as Total_Parties,
 sum(cd.`EVM Votes` + cd.`Postal Votes`) as  Total_Votes ,
 sum(cd.`EVM Votes`) as Total_EVM_Votes ,
 sum(cd.`Postal Votes`) as Total_Postal_Votes
 from constituencywise_results as cr
 join partywise_results as pr 
 on cr.`Party ID` = pr.`Party ID`
 join state_results as sr
 on cr.`Parliament Constituency`=sr.`Parliament Constituency`
 join states as s
 on s.`State ID` = sr.`State ID`
 join constituencywise_details as cd
 on cd.`Constituency ID` = cr.`Constituency ID` 
 where s.State='Maharashtra';
""", engine)

# %%
T13
# Out:
#    Total_Seats  Total_Candidates  Total_Parties  Total_Votes  Total_EVM_Votes  \
# 0            3                76              2    3748130.0        3733135.0
#
#    Total_Postal_Votes
# 0             14995.0

# %% [markdown]
# # task 14 : Which candidate received the highest number of EVM votes in each constituency (Top 10)?

# %%
T14 = pd.read_sql_query("""SELECT 
    cr.`Constituency Name`,
    cd.`Constituency ID`,
    cd.`Candidate`,
    cd.`EVM Votes`
FROM 
    constituencywise_details as  cd
JOIN 
    constituencywise_results as cr 
    ON cd.`Constituency ID` = cr.`Constituency ID`
WHERE 
    cd.`EVM Votes` = (
        SELECT MAX(cd1.`EVM Votes`)
        FROM constituencywise_details as cd1
        WHERE cd1.`Constituency ID` = cd.`Constituency ID`
    )
ORDER BY 
    cd.`EVM Votes` DESC 
    limit 10;

""", engine)

# %%
T14
# Out:
#   Constituency Name Constituency ID                         Candidate  \
# 0    BANGALORENORTH           S1024                 SHOBHA KARANDLAJE
# 1           RAIGARH            S262                RADHESHYAM RATHIYA
# 2            RATLAM           S1224          ANITA NAGARSINGH CHOUHAN
# 3        COOCHBEHAR            S251    JAGADISH CHANDRA BARMA BASUNIA
# 4          RANAGHAT           S2513                  JAGANNATH SARKAR
# 5        ANANTHAPUR           S0119  AMBICA G LAKSHMINARAYANA VALMIKI
# 6          KOLHAPUR           S1347         CHHATRAPATI SHAHU SHAHAJI
# 7             THANE           S1325              NARESH GANPAT MHASKE
# 8          ULUBERIA           S2526                       SAJDA AHMED
# 9          DINDIGUL           S2222                 SACHITHANANTHAM R
#
#    EVM Votes
# 0     982805
# 1     806667
# 2     793432
# 3     785747
# 4     778046
# 5     755862
# 6     750323
# 7     732109
# 8     722586
# 9     667391

# %% [markdown]
# # summary :
#
# # 1.Parliament Constituency have total 543 Seats in INDIA GENERAL ELECTIONS RESULT ANALYSIS 2024
#
# # 2.Total seats won by NDA alliance was 292 seats
#
# # 3.NDA alliance parties like BJP won by 240
